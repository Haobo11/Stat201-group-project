# %% [markdown]
# ## Title

# %% [markdown]
# ### Introduction

# %% [markdown]
# ### Preliminary Data Analysis

# %% [markdown]
# #### Data Processing

# %%
#Load libraries
library(tidyverse)
library(broom)
library(repr)
library(digest)
library(infer)
library(gridExtra)
library(readxl)
library(tidymodels)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.4
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ dials        1.0.0     ✔ tune         1.0.0
# ✔ modeldata    1.0.1     ✔ workflows    1.0.0
# ✔ parsnip      1.0.1     ✔ workflowsets 1.0.0
# ✔ recipes      1.0.1     ✔ yardstick    1.1.0
# ✔ rsample      1.1.0
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ gridExtra::combine() masks dplyr::combine()
# ✖ scales::discard()    masks purrr::discard()
# ✖ dplyr::filter()      masks stats::filter()
# ✖ recipes::fixed()     masks stringr::fixed()
# ✖ dplyr::lag()         masks stats::lag()
# ✖ yardstick::spec()    masks readr::spec()
# ✖ recipes::step()      masks stats::step()
# • Use tidymodels_prefer() to resolve common conflicts.

# %%
#Load dataset from web
crime_data_2021 <- read.csv("https://github.com/Haobo11/stat201-group-project/raw/main/crimedata_csv_Hastings-Sunrise_2021.csv")
crime_data_2022 <- read.csv("https://github.com/Haobo11/stat201-group-project/raw/main/crimedata_csv_Hastings-Sunrise_2022.csv")

#Preview datasets
head(crime_data_2021)
head(crime_data_2022)

n_2021 <- crime_data_2021|>
nrow()
n_2021
# Out:
#   TYPE               YEAR MONTH DAY HOUR MINUTE HUNDRED_BLOCK
# 1 Theft from Vehicle 2021 8     17  21   57     1XX RENFREW ST
# 2 Theft from Vehicle 2021 9     20  20   45     20XX CASSIAR ST
# 3 Theft from Vehicle 2021 3      5   3   30     20XX CASSIAR ST
# 4 Theft from Vehicle 2021 2     15  12    0     21XX KAMLOOPS ST
# 5 Theft from Vehicle 2021 6     28  12    0     21XX LILLOOET ST
# 6 Theft from Vehicle 2021 4     14   3    0     21XX NANAIMO ST
#   NEIGHBOURHOOD    X        Y
# 1 Hastings-Sunrise 496804.9 5459011
# 2 Hastings-Sunrise 497740.0 5457015
# 3 Hastings-Sunrise 497740.0 5457017
# 4 Hastings-Sunrise 496024.4 5456995
# 5 Hastings-Sunrise 497165.9 5456990
# 6 Hastings-Sunrise 495887.6 5456922
#   TYPE               YEAR MONTH DAY HOUR MINUTE HUNDRED_BLOCK
# 1 Theft from Vehicle 2022 5      3  22    0     1XX KOOTENAY ST
# 2 Theft from Vehicle 2022 5     26   7   30     1XX N RENFREW ST
# 3 Theft from Vehicle 2022 1     10  18    0     1XX NANAIMO ST
# 4 Theft from Vehicle 2022 9     25  17   55     1XX RENFREW ST
# 5 Theft from Vehicle 2022 4     29  20    0     20XX KAMLOOPS ST
# 6 Theft from Vehicle 2022 8     27   2    0     20XX NANAIMO ST
#   NEIGHBOURHOOD    X        Y
# 1 Hastings-Sunrise 498134.7 5458960
# 2 Hastings-Sunrise 496800.4 5459316
# 3 Hastings-Sunrise 495893.3 5459013
# 4 Hastings-Sunrise 496795.9 5458959
# 5 Hastings-Sunrise 496024.4 5457091
# 6 Hastings-Sunrise 495887.8 5457043
# [1] 1184

# %%
samples_2021 <- crime_data_2021 |>
rep_sample_n(size = 30, reps = 10000, replace = TRUE) |>
group_by(replicate) |>
summarize(sample_pro = mean(TYPE == "Theft from Vehicle"))

samples_2022 <- crime_data_2022 |>
rep_sample_n(size = 30, reps = 10000, replace = TRUE) |>
group_by(replicate) |>
summarize(sample_pro = mean(TYPE == "Theft from Vehicle"))


sampling_dist_2021 <- samples_2021|>
ggplot()+
geom_histogram(aes(x= sample_pro), binwidth = 0.04) +
xlab("The sample proportion") +
ggtitle("The 2021 sampling proportion distribution")

sampling_dist_2022 <- samples_2022|>
ggplot()+
geom_histogram(aes(x= sample_pro), binwidth = 0.04) +
xlab("The sample proportion") +
ggtitle("The 2021 sampling proportion distribution")

sampling_dist_2021
sampling_dist_2022
# Out:
# plot without title
# plot without title

# %%
# Calculate the number of crime which type is Theft from Vehicle
# respectively in 2021 and 2022 and the total number of the crimes
# in 2021 and 2022
n_2021 <- nrow(crime_data_2021)

n_2022 <- nrow(crime_data_2022)

n_2021_tfv <- crime_data_2021|>
filter(TYPE == "Theft from Vehicle") |>
nrow()

n_2022_tfv <- crime_data_2022|>
filter(TYPE == "Theft from Vehicle") |>
nrow()

# Calculate the Theft from Vehicle respectively in 2021 and 2022
p_2021 <- n_2021_tfv/n_2021
p_2022 <- n_2022_tfv/n_2022

# Calculate the pooled proportion
p_p <- (n_2021_tfv+n_2022_tfv)*(n_2021 + n_2022)^(-1)


# Calculate the test_statistic
test_statistic <- (p_2021 - p_2022)/sqrt(p_p*(1-p_p)*(1/n_2021_tfv+1/n_2022_tfv))
test_statistic
#Calculate the p-value
p_value <- pnorm(test_statistic, mean = 0, sd = 1, lower.tail = FALSE)
p_value
#Finally let us do the prop test
prop_test <- tidy(
        prop.test(x = c(n_2021_tfv, n_2022_tfv), # an array with the number of successes in each sample
                  n = c(n_2021, n_2022), # an array with the size of each sample
                  correct = FALSE, alternative = "greater"))
prop_test
# Out:
# [1] 1.4162
# [1] 0.07835845
#   estimate1 estimate2 statistic p.value    parameter conf.low   conf.high
# 1 0.3251689 0.2729189 6.823414  0.00449852 1         0.01958279 1
#   method
# 1 2-sample test for equality of proportions without continuity correction
#   alternative
# 1 greater

# %%
#Tidying data
theft_vehicle <- rbind(crime_data_2021, crime_data_2022) %>%   #combining dataframes
    select(TYPE, YEAR) %>%   #selecting only columns with the type of crime and year it occurred
    mutate(TYPE = if_else(TYPE == "Theft of Bicycle", "Other", TYPE),   
           TYPE = if_else(TYPE == "Theft of Vehicle", "Other", TYPE),
           TYPE = if_else(TYPE == "Vehicle Collision or Pedestrian Struck (with Fatality)", "Other", TYPE),
           TYPE = if_else(TYPE == "Vehicle Collision or Pedestrian Struck (with Injury)", "Other", TYPE),
           TYPE = if_else(TYPE == "Break and Enter Commercial", "Other", TYPE),
           TYPE = if_else(TYPE == "Break and Enter Residential/Other", "Other", TYPE),
           TYPE = if_else(TYPE == "Homicide", "Other", TYPE),
           TYPE = if_else(TYPE == "Mischief", "Other", TYPE),
           TYPE = if_else(TYPE == "Offence Against a Person", "Other", TYPE),
           TYPE = if_else(TYPE == "Other Theft", "Other", TYPE))   #separating crime of interest, Theft from Vehicle, from other crimes

#Changing YEAR variables from integer to factor
theft_vehicle$YEAR <- as.factor(theft_vehicle$YEAR)

head(theft_vehicle)
# Out:
#   TYPE               YEAR
# 1 Theft from Vehicle 2021
# 2 Theft from Vehicle 2021
# 3 Theft from Vehicle 2021
# 4 Theft from Vehicle 2021
# 5 Theft from Vehicle 2021
# 6 Theft from Vehicle 2021

# %% [markdown]
# #### Visualization

# %%
#Visualizing the proportion of crimes that were Theft from Vehicle
theft_vehicle_plot <- theft_vehicle %>%
    ggplot() +
        geom_bar(aes(x = YEAR, fill = TYPE), position = "fill") +
        labs(x = "Year", y = "Proportion", fill = "Type of Crime") +
        ggtitle("Proportion of Theft from Vehicle Crimes in 2021 and 2022 in Hastings-Sunrise")
theft_vehicle_plot
# Out:
# plot without title

# %% [markdown]
# **Figure 1.** Visualization of the proportion of crimes occuring in 2021 and 2022 that were theft from vehicle in the Hastings-Sunrise neighbourhood in Metro Vancouver

# %% [markdown]
# As we can see in **Fig. 1**, the proportion of crimes in 2021 that were theft from vehicle was slightly higher than in 2022. However, we cannot conclude whether this is a significant difference or not just from the visualization alone; therefore hypothesis testing will be performed to determine whether the difference in proportions is statistically significant.

# %% [markdown]
# ### Methods

# %% [markdown]
# #### Project Trustworthiness:
#
# - Our database from the Vancouver Police Department is both authoritative and representative, making it a reliable source for analyse crime conclusions about Hastings-Sunrise community.
#
# - In the previous section, we carefully sorted and arranged the initial data by removing any unnecessary variables and attributes. By taking these necessary steps, we can minimize the chances of errors in our operations and ensure that this report is dependable.
#
# - The dataset we are utilizing has a sufficiently large sample size of approximately 2000 observations, which will minimize any potential sampling bias.
#
# #### Reasoning why plots and estimates are not enough:
#
# Our dataset only captures reported criminal incidents, and therefore may not fully represent the entire population of criminal incidents in Vancouver. As a result, there may be some degree of bias between the values analyzed and calculated in our report and the actual population parameter, since we don't have access to the full population data.
#
# To compare the proportions of two independent populations when we don't know their mean, standard deviation, and distribution,  we can use a two-sample z-test to calculate the test statistic and confidence intervals based on the central limit theorem. Since our sample size is large enough, we can rely on the CLT to conduct our hypothesis test.
#
# #### Project Expectiaton：
#
# We expect to compare the significant difference between 2022 and 2021 in the proportion of Theft of Vehicles among all crime types.
#
# #### Project Impact:
#
# - As both Vancouver crime datasets used in our report are the most recent data from the past two years, it can serve as a reliable source for analyzing the current crime situation in Vancouver.
#
# - Additionally, our report can assist in predicting future criminal trends in Vancouver based on the analysis of the current data.
#
# - This information can be used to develop targeted strategies for reducing crime and improving community safety in that specific neighborhood.
#
# #### Feture questions:
# - Which Type of crime has the highest proportion?
#
# - Is there a relationship between the time of the crime and the type of crime?
#
# - What time of the year is the most frequent time of the crime?

# %% [markdown]
# ### References
